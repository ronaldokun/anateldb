# %% [raw]
# ---
# output-file: constants.html
# title: Constantes
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Links

# %% [markdown]
# ## Listas

# %% [markdown]
# ## Dicionários

# %% [markdown]
# ## QUERIES

# %% [markdown]
# ## Regex

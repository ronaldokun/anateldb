# %% [raw]
# ---
# description: "Este m\xF3dulo atualiza as bases. Executa as queries sql do STEL, RADCOM\
#   \ e baixa os arquivos de esta\xE7\xF5es e plano b\xE1sico do MOSAICO."
# output-file: updates.html
# title: "Atualiza\xE7\xE3o"
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Conexão com o banco de dados
# A função a seguir é um `wrapper` simples que utiliza o `pyodbc` para se conectar ao banco de dados base da Anatel e retorna o objeto da conexão

# %%
#| echo: false
#| output: asis
show_doc(connect_db)
# Out:
# ---
#
# [source](https://github.com/ronaldokun/anateldb/blob/master/extracao/updates.py#L29){target="_blank" style="float:right; font-size:smaller"}
#
# ### connect_db
#
# >      connect_db (server:str='ANATELBDRO05', database:str='SITARWEB',
# >                  trusted_conn:str='yes', mult_results:bool=True)
#
# Conecta ao Banco `server` e retorna o 'cursor' (iterador) do Banco
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | server | str | ANATELBDRO05 | Servidor do Banco de Dados |
# | database | str | SITARWEB | Nome do Banco de Dados |
# | trusted_conn | str | yes | Conexão Segura: yes \| no |
# | mult_results | bool | True | Múltiplos Resultados |
# | **Returns** | **Connection** |  |  |

# %%
#echo: false
def test_connection():
    conn = connect_db()
    cursor = conn.cursor()
    for query in (SQL_RADCOM,SQL_STEL):
        cursor.execute(query)
        test_eq(type(cursor.fetchone()), pyodbc.Row)

# %%
#| eval: false
test_connection()

# %%
#| echo: false
#| output: asis
show_doc(clean_mosaico)
# Out:
# ---
#
# [source](https://github.com/ronaldokun/anateldb/blob/master/extracao/updates.py#L46){target="_blank" style="float:right; font-size:smaller"}
#
# ### clean_mosaico
#
# >      clean_mosaico (df:pandas.core.frame.DataFrame,
# >                     pasta:Union[str,pathlib.Path])
#
# Clean the merged dataframe with the data from the MOSAICO page
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | df | DataFrame | DataFrame com os dados de Estações e Plano_Básico mesclados |
# | pasta | Union | Pasta com os dados de municípios para imputar coordenadas ausentes |
# | **Returns** | **DataFrame** | **DataFrame com os dados mesclados e limpos** |

# %% [markdown]
# ## Atualização das bases de dados
# As bases de dados são atualizadas atráves das funções a seguir, o único argumento passado em todas elas é a pasta na qual os arquivos locais processados serão salvos, os nomes dos arquivos são padronizados e não podem ser editados para que as funções de leitura e processamento recebam somente a pasta na qual esses arquivos foram salvos.

# %%
#| echo: false
#| output: asis
show_doc(update_radcom)
# Out:
# ---
#
# [source](https://github.com/ronaldokun/anateldb/blob/master/extracao/updates.py#L90){target="_blank" style="float:right; font-size:smaller"}
#
# ### update_radcom
#
# >      update_radcom (conn:pyodbc.Connection, folder:Union[str,pathlib.Path])
#
# Atualiza a tabela local retornada pela query `RADCOM`, com tratamento de erro de conectividade.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | conn | Connection | Objeto de conexão de banco |
# | folder | Union | Pasta onde salvar os arquivos |
# | **Returns** | **DataFrame** | **DataFrame com os dados atualizados** |

# %%
#| eval: false
import warnings
# warnings.filterwarnings("ignore", message='install "ipywidgets" for Jupyter support')
warnings.filterwarnings("ignore")

# %%
#| eval: false
folder = Path.cwd().parent / 'dados'
conn = connect_db()
radcom = update_radcom(conn, folder)
radcom
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#      Frequência                                           Entidade  \
# 0          87.5  ASSOCIACAO COMUNITARIA VOZ DA LIBERDADE DE TUR...
# 1          87.5  ASSOCIACAO COMUNITARIA DO MORAD.DE ALVORADA DE...
# 2          87.5  ASSOCIAÇÃO COMUNITARIA DA JUVENTUDE DE CONGONH...
# 3          87.5                     ASSOCIACAO COMUNITARIA FOLHETA
# 4          87.5  ASSOCIAÇÃO DE RÁDIO COMUNITÁRIA DE CASTANHEIRA...
# ...         ...                                                ...
# 4918      107.9                    ASSOCIAÇÃO CULT COMUNIT MORUMBI
# 4919      107.9  ASSOCIAÇÃO DE MORADORES DO JARDIM CRISTINA OUR...
# 4920      107.9  ASSOCIAÇÃO DE MORADORES DO JARDIM CRISTINA OUR...
# 4921      107.9  ASSOCIACAO COMUNITARIA CULTURAL DE MUSICA E CI...
# 4922      107.9  ASSOCIAÇÃO DE MORADORES DO JARDIM CRISTINA OUR...
#
#            Fistel Número_Estação            Município Código_Município  UF  \
# 0     50415095220     1008210959           Turilândia          2112456  MA
# 1     50409064718      699491851    Alvorada de Minas          3102407  MG
# 2     50405625782      699359830   Congonhas do Norte          3118106  MG
# 3     50404381251      690859562          Dom Joaquim          3122603  MG
# 4     50411566547     1008401606          Castanheira          5102850  MT
# ...           ...            ...                  ...              ...  ..
# 4918  50407431578      697707695  São José dos Campos          3549904  SP
# 4919  50413097013      692270272  São José dos Campos          3549904  SP
# 4920  50434484237      692270272  São José dos Campos          3549904  SP
# 4921  50406778205      693049723  São José dos Campos          3549904  SP
# 4922  50406232911      692270272  São José dos Campos          3549904  SP
#
#                  Latitude            Longitude Classe Num_Serviço  \
# 0         -2.228611111111  -45.306666666666665      P         231
# 1     -18.734166666666667   -43.36472222222217      3         231
# 2     -18.812777777777665     -43.673611111111      3         231
# 3                  -18.95  -43.266666666666666      3         231
# 4     -11.137222222222167   -58.61333333333334    P-A         231
# ...                   ...                  ...    ...         ...
# 4918  -23.267777777777667             -45.8975    3-B         231
# 4919    -23.5530555555555    -45.8705555555555      3         231
# 4920    -23.5530555555555    -45.8705555555555      3         231
# 4921  -23.191944444444335   -45.87527777777767      3         231
# 4922    -23.5530555555555    -45.8705555555555      3         231
#
#      Classe_Emissão Largura_Emissão(kHz) Validade_RF  Status Fonte  \
# 0              <NA>                  256        <NA>  RADCOM   SRD
# 1              <NA>                  256        <NA>  RADCOM   SRD
# 2              <NA>                  256        <NA>  RADCOM   SRD
# 3              <NA>                  256        <NA>  RADCOM   SRD
# 4              <NA>                  256        <NA>  RADCOM   SRD
# ...             ...                  ...         ...     ...   ...
# 4918           <NA>                  256        <NA>  RADCOM   SRD
# 4919           <NA>                  256        <NA>  RADCOM   SRD
# 4920           <NA>                  256        <NA>  RADCOM   SRD
# 4921           <NA>                  256        <NA>  RADCOM   SRD
# 4922           <NA>                  256        <NA>  RADCOM   SRD
#
#      Multiplicidade
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# ...             ...
# 4918              1
# 4919              1
# 4920              1
# 4921              1
# 4922              1
#
# [4923 rows x 17 columns]

# %%
#| echo: false
#| output: asis
show_doc(update_stel)
# Out:
# ---
#
# [source](https://github.com/ronaldokun/anateldb/blob/master/extracao/updates.py#L133){target="_blank" style="float:right; font-size:smaller"}
#
# ### update_stel
#
# >      update_stel (conn:pyodbc.Connection, folder:Union[str,pathlib.Path])
#
# Atualiza a tabela local retornada pela query `STEL`, com tratamento de erro de conectividade.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | conn | Connection | Objeto de conexão de banco |
# | folder | Union | Pasta onde salvar os arquivos |
# | **Returns** | **DataFrame** | **DataFrame com os dados atualizados** |

# %%
#| eval: false
stel = update_stel(conn, folder)
stel
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       Frequência                                           Entidade  \
# 0          10620             GLOBO COMUNICAÇÃO E PARTICIPAÇÕES S.A.
# 1          10795                 CENTER PRESTADORA DE SERVICOS LTDA
# 2          10835                        WIRELESS COMM SERVICES LTDA
# 3          10835                    PLIM TELECOMUNICACOES LTDA - ME
# 4          10835                              PRONTO NET LTDA - EPP
# ...          ...                                                ...
# 68712     25.375             HOSPITAL NOSSA SENHORA DA CONCEICAO SA
# 68713     25.375  REAL E BENEMERITA ASSOCIACAO PORTUGUESA DE BEN...
# 68714     25.375                   SOCIEDADE BENEFICENTE SAO CAMILO
# 68715     25.375  UNIMED PAULISTANA SOC COOPERATIVA DE TRABALHO ...
# 68716     26.145                  PETROLEO BRASILEIRO S A PETROBRAS
#
#             Fistel Número_Estação        Município Código_Município  UF  \
# 0      02030460486        1920804        São Paulo          3550308  SP
# 1      50408047330      695507990  Poços de Caldas          3151800  MG
# 2      50409293075     1009057747   Rio de Janeiro          3304557  RJ
# 3      50411369989     1003949670    Montes Claros          3143302  MG
# 4      50409704636     1000978106          Santana          1600600  AP
# ...            ...            ...              ...              ...  ..
# 68712  50417771525     1008302110     Porto Alegre          4314902  RS
# 68713  50404519970     1008765764        São Paulo          3550308  SP
# 68714  50406930287      692391789        São Paulo          3550308  SP
# 68715  50407957189      696380056        São Paulo          3550308  SP
# 68716  50411168908     1010531651            Cairu          2905404  BA
#
#                   Latitude            Longitude Classe Num_Serviço  \
# 0      -23.564722222222166     -46.651111111111     TX         728
# 1         -21.772861111111   -46.57452777777767     FX         046
# 2                -22.82545     -43.527561111111     FX         046
# 3      -16.947577777777667    -43.8624055555555     FX         046
# 4      -0.0414222222221666    -51.1732805555555     FX         046
# ...                    ...                  ...    ...         ...
# 68712  -30.010194444444334  -51.159388888888834     TX         060
# 68713  -23.567138888888834   -46.64113888888883     TX         060
# 68714  -23.487777777777666  -46.627444444444336     TX         060
# 68715  -23.562277777777666   -46.63858333333334     TX         060
# 68716  -13.490008333333334  -38.812241666666665     FC         604
#
#       Classe_Emissão Largura_Emissão(kHz) Validade_RF Status Fonte  \
# 0                F8W              18000.0  2020-01-05      L  STEL
# 1                D7W              39600.0  2021-05-02      L  STEL
# 2                D7D              40000.0  2027-08-17      L  STEL
# 3                D7W              40000.0  2032-07-12      L  STEL
# 4                D7W              40000.0  2028-03-27      L  STEL
# ...              ...                  ...         ...    ...   ...
# 68712            F9W                 25.0  2039-04-08      L  STEL
# 68713            F9W                 25.0  2037-05-08      L  STEL
# 68714            F9W                 25.0  2040-05-05      L  STEL
# 68715            F9W                 25.0  2026-09-01      L  STEL
# 68716            J3E                  2.7  2033-12-03      L  STEL
#
#       Multiplicidade
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 68712              1
# 68713              1
# 68714              1
# 68715              1
# 68716              1
#
# [68717 rows x 17 columns]

# %%
#| echo: false
#| output: asis
show_doc(update_mosaico)
# Out:
# ---
#
# [source](https://github.com/ronaldokun/anateldb/blob/master/extracao/updates.py#L178){target="_blank" style="float:right; font-size:smaller"}
#
# ### update_mosaico
#
# >      update_mosaico (mongo_client:pymongo.mongo_client.MongoClient,
# >                      folder:Union[str,pathlib.Path])
#
# Efetua a query na tabela de Radiodifusão no banco mongoDB `mongo_client` e atualiza o arquivo local
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | mongo_client | MongoClient | Objeto de conexão com o MongoDB |
# | folder | Union | Pasta onde salvar os arquivos |
# | **Returns** | **DataFrame** | **DataFrame com os dados atualizados** |

# %%
#|eval: false
uri = input()
mongo_client = MongoClient(uri)
mongo_client.server_info()
# Out:
# {'version': '4.0.5',
#  'gitVersion': '3739429dd92b92d1b0ab120911a23d50bf03c412',
#  'targetMinOS': 'Windows 7/Windows Server 2008 R2',
#  'modules': [],
#  'allocator': 'tcmalloc',
#  'javascriptEngine': 'mozjs',
#  'sysInfo': 'deprecated',
#  'versionArray': [4, 0, 5, 0],
#  'openssl': {'running': 'Windows SChannel'},
#  'buildEnvironment': {'distmod': '2008plus-ssl',
#   'distarch': 'x86_64',
#   'cc': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.00.24223 for x64',
#   'ccflags': '/nologo /EHsc /W3 /wd4355 /wd4800 /wd4267 /wd4244 /wd4290 /wd4068 /wd4351 /wd4373 /we4013 /we4099 /we4930 /WX /errorReport:none /MD /O2 /Oy- /bigobj /utf-8 /Zc:rvalueCast /Zc:strictStrings /volatile:iso /Gw /Gy /Zc:inline',
#   'cxx': 'cl: Microsoft (R) C/C++ Optimizing Compiler Version 19.00.24223 for x64',
#   'cxxflags': '/TP',
#   'linkflags': '/nologo /DEBUG /INCREMENTAL:NO /LARGEADDRESSAWARE /OPT:REF',
#   'target_arch': 'x86_64',
#   'target_os': 'windows'},
#  'bits': 64,
#  'debug': False,
#  'maxBsonObjectSize': 16777216,
#  'storageEngines': ['devnull', 'ephemeralForTest', 'mmapv1', 'wiredTiger'],
#  'ok': 1.0}

# %%
#|eval: false
mosaico = update_mosaico(mongo_client, folder)
mosaico
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       Frequência                           Entidade       Fistel  \
# 0          207.0  REDE DE COMUNICACOES ACREANA LTDA  50442889933
# 1          539.0                  X-MEDIAGROUP S.A.  50410887137
# 2           79.0        TELEVISAO OESTE BAIANO LTDA  06030116240
# 3           69.0          TELEVISAO SANTA CRUZ LTDA  06020355110
# 4          177.0                   TV CABRALIA LTDA  06020354903
# ...          ...                                ...          ...
# 30138      569.0           TV MARANHAO CENTRAL LTDA  50443805717
# 30139      563.0           TV MARANHAO CENTRAL LTDA  50443805806
# 30140      569.0           TV MARANHAO CENTRAL LTDA  50443805989
# 30141      563.0           TV MARANHAO CENTRAL LTDA  50443806101
# 30142      617.0                     PARANA FM LTDA  50443843805
#
#       Número_Estação                     Município Código_Município  UF  \
# 0               <NA>               Cruzeiro do Sul          1200203  AC
# 1               <NA>                   Mâncio Lima          1200336  AC
# 2          322647029                     Barreiras          2903201  BA
# 3          322623553                       Itabuna          2914802  BA
# 4          322623537                       Itabuna          2914802  BA
# ...              ...                           ...              ...  ..
# 30138           <NA>               Poção de Pedras          2108900  MA
# 30139           <NA>  São Luís Gonzaga do Maranhão          2111409  MA
# 30140           <NA>             Trizidela do Vale          2112233  MA
# 30141           <NA>               Vitorino Freire          2113009  MA
# 30142           <NA>                    Santa Inês          2109908  MA
#
#                    Latitude             Longitude Classe Num_Serviço  \
# 0                      <NA>                  <NA>      A         248
# 1                      <NA>                  <NA>      C         248
# 2      -12.1013888888888333  -44.9936111111110000      A         248
# 3      -14.7794444444443333  -39.2622222222221666      A         248
# 4      -14.7833333333333333  -39.2833333333333333      B         248
# ...                     ...                   ...    ...         ...
# 30138                  <NA>                  <NA>      C         801
# 30139                  <NA>                  <NA>      C         801
# 30140                  <NA>                  <NA>      C         801
# 30141                  <NA>                  <NA>      C         801
# 30142                  <NA>                  <NA>      C         801
#
#       Classe_Emissão Largura_Emissão(kHz) Validade_RF Status Fonte  \
# 0               <NA>               6000.0        <NA>  TV-C1   MOS
# 1               <NA>               6000.0        <NA>  TV-C1   MOS
# 2               <NA>               6000.0  2023-12-31  TV-C4   MOS
# 3               <NA>               6000.0  2023-12-31  TV-C4   MOS
# 4               <NA>               6000.0  2023-12-31  TV-C4   MOS
# ...              ...                  ...         ...    ...   ...
# 30138           <NA>               5700.0        <NA>  TV-C1   MOS
# 30139           <NA>               5700.0        <NA>  TV-C1   MOS
# 30140           <NA>               5700.0        <NA>  TV-C1   MOS
# 30141           <NA>               5700.0        <NA>  TV-C1   MOS
# 30142           <NA>               5700.0        <NA>  TV-C1   MOS
#
#       Multiplicidade
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1
# ...              ...
# 30138              1
# 30139              1
# 30140              1
# 30141              1
# 30142              1
#
# [30143 rows x 17 columns]

# %%
#| echo: false
#| output: asis
show_doc(update_telecom)
# Out:
# ---
#
# [source](https://github.com/ronaldokun/anateldb/blob/master/extracao/updates.py#L206){target="_blank" style="float:right; font-size:smaller"}
#
# ### update_telecom
#
# >      update_telecom (mongo_client:pymongo.mongo_client.MongoClient,
# >                      folder:Union[str,pathlib.Path])
#
# Efetua a query na tabela `licenciamento` no banco mongoDB `mongo_client` e atualiza o arquivo local
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | mongo_client | MongoClient | Objeto de conexão com o MongoDB |
# | folder | Union | Pasta onde salvar os arquivos |
# | **Returns** | **DataFrame** | **DataFrame com os dados atualizados** |

# %%
#| eval: false
telecom = update_telecom(mongo_client, folder)
telecom
# Out:
# 0it [00:00, ?it/s]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#     Frequência                                   Entidade       Fistel  \
# 0     469.1625  AMS TECNOLOGIA & RADIOCOMUNICACAO LTDA ME  50407701621
# 1       469.35  AMS TECNOLOGIA & RADIOCOMUNICACAO LTDA ME  50407701621
# 2     469.8375  AMS TECNOLOGIA & RADIOCOMUNICACAO LTDA ME  50407701621
# 3     459.1625  AMS TECNOLOGIA & RADIOCOMUNICACAO LTDA ME  50407701621
# 4       459.35  AMS TECNOLOGIA & RADIOCOMUNICACAO LTDA ME  50407701621
# ..         ...                                        ...          ...
# 292      733.0                     TELEFONICA BRASIL S.A.  50419058354
# 293     1770.0                     TELEFONICA BRASIL S.A.  50419058354
# 294      469.5             VITEL V3 TELECOMUNICACOES LTDA  50408917849
# 295     459.05             VITEL V3 TELECOMUNICACOES LTDA  50408917849
# 296     469.05             VITEL V3 TELECOMUNICACOES LTDA  50408917849
#
#     Número_Estação Município Código_Município  UF    Latitude   Longitude  \
# 0       1014104553  Campinas          3509502  SP    -22.8275  -47.032778
# 1       1014104553  Campinas          3509502  SP    -22.8275  -47.032778
# 2       1014104553  Campinas          3509502  SP    -22.8275  -47.032778
# 3       1014104561  Campinas          3509502  SP    -22.8275  -47.032778
# 4       1014104561  Campinas          3509502  SP    -22.8275  -47.032778
# ..             ...       ...              ...  ..         ...         ...
# 292     1014172079   Vitória          3205309  ES  -21.906383  -39.236117
# 293     1014172052   Vitória          3205309  ES  -21.906383  -39.236117
# 294      697386821      <NA>          3304557  RJ  -22.830667  -43.319194
# 295     1010113175      <NA>          3304557  RJ   -22.83725  -43.316056
# 296     1010113167      <NA>          3304557  RJ   -22.83725  -43.316056
#
#     Classe Num_Serviço Classe_Emissão Largura_Emissão(kHz) Validade_RF Status  \
# 0       FB         017             -1                 -1.0  2041-03-24      L
# 1       FB         017             -1                 -1.0  2041-03-24      L
# 2       FB         017             -1                 -1.0  2041-03-24      L
# 3       ML         017             -1                 -1.0  2041-03-24      L
# 4       ML         017             -1                 -1.0  2041-03-24      L
# ..     ...         ...            ...                  ...         ...    ...
# 292     ML         011            G7W               5000.0  2029-12-08      L
# 293     ML         011            G7W               5000.0  2029-12-08      L
# 294     ML         017            F1E                 12.5  2032-05-07      L
# 295     ML         017            F1W                  7.6  2032-05-07      L
# 296     ML         017            F1W                  7.6  2032-05-07      L
#
#     Fonte Multiplicidade
# 0     MOS              1
# 1     MOS              1
# 2     MOS              1
# 3     MOS              6
# 4     MOS              6
# ..    ...            ...
# 292   MOS              3
# 293   MOS              3
# 294   MOS              1
# 295   MOS              2
# 296   MOS              1
#
# [297 rows x 17 columns]

# %%
#| echo: false
#| output: asis
show_doc(valida_coords)
# Out:
# ---
#
# [source](https://github.com/ronaldokun/anateldb/blob/master/extracao/updates.py#L268){target="_blank" style="float:right; font-size:smaller"}
#
# ### valida_coords
#
# >      valida_coords (conn:pyodbc.Connection, row:pandas.core.series.Series)
#
# Valida os dados de coordenadas e município em `row` no polígono dos municípios em banco corporativo
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | conn | Connection | Objeto de conexão de banco |
# | row | Series | Linha de um DataFrame |
# | **Returns** | **tuple** | **DataFrame com dados do município** |

# %%
#| echo: false
#| output: asis
show_doc(update_base)
# Out:
# ---
#
# [source](https://github.com/ronaldokun/anateldb/blob/master/extracao/updates.py#L293){target="_blank" style="float:right; font-size:smaller"}
#
# ### update_base
#
# >      update_base (conn:pyodbc.Connection,
# >                   clientMongoDB:pymongo.mongo_client.MongoClient,
# >                   folder:Union[str,pathlib.Path])
#
# Wrapper que atualiza opcionalmente lê e atualiza as 4 bases indicadas anteriormente, as combina e salva o arquivo consolidado na folder `folder`
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | conn | Connection | Objeto de conexão de banco |
# | clientMongoDB | MongoClient | Ojeto de conexão com o MongoDB |
# | folder | Union | Pasta onde salvar os arquivos |
# | **Returns** | **DataFrame** | **DataFrame com os dados atualizados** |

# %%
#| eval: false
base = update_base(conn, mongo_client, folder)
base
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0it [00:00, ?it/s]
# Output()
